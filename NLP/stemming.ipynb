# %% [markdown]
# # Stemming
# - Process of reducing words to  its stem that affixes to suffixes and prefixes or to the roots of words known as lemma.
# -  used in classification problems e.g. email spam/ham
# -  going,gone,goes--->go

# %%
words = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# ### PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word + " -----> " + stemming.stem(word))
# Out:
# eating -----> eat
# eats -----> eat
# eaten -----> eaten
# writing -----> write
# writes -----> write
# programming -----> program
# programs -----> program
# history -----> histori
# finally -----> final
# finalized -----> final

# %%
stemming.stem('sitting')
# Out:
# 'sit'

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %% [markdown]
# ### RegexpStemmer class
# With the help of this class we can easily implement Regular Expression Stemmer algorithms. It basically takes a regular expression and removes any prefix or suffix that matches the expression
#
# (regexp: Any, min: int = 0) -> RegexpStemmer
# regexp : str or regexp
# The regular expression that should be used to identify morphological affixes.
#
#
# A stemmer that uses regular expressions to identify morphological affixes. Any substrings that match the regular expressions will be removed.

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$|ized$|ly',min=4)

# %%
for word in words:
    print(word + " -----> " + reg_stemmer.stem(word))
# Out:
# eating -----> eat
# eats -----> eat
# eaten -----> eaten
# writing -----> writ
# writes -----> write
# programming -----> programm
# programs -----> program
# history -----> history
# finally -----> final
# finalized -----> final

# %% [markdown]
# ### SnowBall Stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowBallStemmer = SnowballStemmer('english')

# %%
for word in words:
    print(word + " -----> " + snowBallStemmer.stem(word))
# Out:
# eating -----> eat
# eats -----> eat
# eaten -----> eaten
# writing -----> write
# writes -----> write
# programming -----> program
# programs -----> program
# history -----> histori
# finally -----> final
# finalized -----> final

# %%
stemming.stem("sportingly"),snowBallStemmer.stem('sportingly'),reg_stemmer.stem("sportingly")
# Out:
# ('sportingli', 'sport', 'sporting')
