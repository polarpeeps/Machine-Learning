# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\nabee\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\nabee\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\nabee\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nabee\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\nabee\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\nabee\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus = """
Hello Welcome, to Nabeel Rizvi's NLP Tutorials.
Please do watch the entire course! to become expert in NLP. 
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Nabeel Rizvi's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\nabee\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
documents=sent_tokenize(corpus)
documents
# Out:
# ["\nHello Welcome, to Nabeel Rizvi's NLP Tutorials.",
#  'Please do watch the entire course!',
#  'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to Nabeel Rizvi's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %% [markdown]
# ### Tokenization
# #### Paragraphs ----> Sentence
# #### Sentence ----> Words

# %%
from nltk.tokenize import word_tokenize

# %%
words = word_tokenize(corpus)
words
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Nabeel',
#  'Rizvi',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Nabeel', 'Rizvi', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
punct = wordpunct_tokenize(corpus)
punct
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Nabeel',
#  'Rizvi',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Nabeel',
#  'Rizvi',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
